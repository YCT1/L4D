# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import math
import random
import seaborn as sns
from sklearn.model_selection import KFold
df1 = pd.read_csv("train1.csv") 
df2 = pd.read_csv("train2.csv") 
df2m = pd.read_csv("train2_modified.csv") #will be used in Part D

# %%
#By printing a dataframe, you can view the data in csv format
print(df1)
# Out:
#            x1        x2    y
# 0    4.786214  4.650073  1.0
# 1    3.170196  4.005515  1.0
# 2    5.000920  4.897350  1.0
# 3    4.522969  6.215182  0.0
# 4    3.599857  5.564085  0.0
# ..        ...       ...  ...
# 195  3.450067  4.522179  1.0
# 196  4.621823  6.202977  1.0
# 197  3.633474  3.684436  1.0
# 198  3.729999  5.425063  1.0
# 199  5.104393  6.337585  1.0
#
# [200 rows x 3 columns]

# %%
#You can extract keys from dataframe, which you can use to extract features or labels.
print(df1.keys())
df1_x1 = df1['x1']
df1_x2 = df1['x2']
#To extract data as numpy array:
df1_numpy = df1.values
#You can also extract a specific feature as numpy array as well.
df1_x1_numpy = df1['x1'].values
# Out:
# Index(['x1', 'x2', 'y'], dtype='object')

# %% [markdown]
# # Add your comments as markdown cells(This is a markdown cell).
#
# ## To add a markdown cell, simply click on a cell, then click on the 'Cell' tab above, change 'Cell Type' to 'Markdown'
#
# Then add your comment! To view the format of this markdown cell, double click on here.
#
# ### Note: We provide you with example codes for starter, but feel free to delete anything we provide and write your own code, as long as you use allowed libraries and modules.

# %% [markdown]
# ## Part A: Examine training sets

# %%
#PART A: Examine training sets here. plots etc.
#Hint: df1_class0 = df1[df1['column_name']==0] creates a new dataframe and includes samples (rows) whose class values are 0
#hint: for data distribution plots use plt.scatter(x-axis,y-axis,other params. check online)
#Hint: for each new plot use plt.figure() so they won't overlap, one on top of another
#-------
#to plot cov. matrices you may use following code: (compute 'cov_mtrx' by yourself)
alpha = ['x1', 'x2']
fig = plt.figure()
ax = fig.add_subplot(111)
cov_mtrx = np.cov(df1_numpy, bias=True)
cax = ax.matshow(cov_mtrx,interpolation='nearest') #cov. matrix of dataset1
fig.colorbar(cax)
ax.set_xticklabels(['']+alpha)
ax.set_yticklabels(['']+alpha)
sns.scatterplot(ax= [1,2], data=df1, x="x1", y="x2", s=100)

#---------
#for the histogram plots use plt.hist() (Remember: 4 of them we want)
#for title use: plt.gca().set(title='Data distribution of feature x of trainingSet y', ylabel='Frequency')
# Out:
# <ipython-input-9-ed5916321db2>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['']+alpha)
# <ipython-input-9-ed5916321db2>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['']+alpha)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ed5916321db2> in <module>
#      13 ax.set_xticklabels(['']+alpha)
#      14 ax.set_yticklabels(['']+alpha)
# ---> 15 sns.scatterplot(ax= [1,2], data=df1, x="x1", y="x2", s=100)
#      16
#      17 #---------
#
# c:\users\yekta\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\yekta\appdata\local\programs\python\python39\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     816         return ax
#     817
# --> 818     p._attach(ax)
#     819
#     820     p.plot(ax, kwargs)
#
# c:\users\yekta\appdata\local\programs\python\python39\lib\site-packages\seaborn\_core.py in _attach(self, obj, allowed_types, log_scale)
#    1125             # its mapping, meaning that it won't handle unshared axes well either.
#    1126             for ax in ax_list:
# -> 1127                 axis = getattr(ax, f"{var}axis")
#    1128                 seed_data = self.plot_data[var]
#    1129                 if var_type == "categorical":
#
# AttributeError: 'list' object has no attribute 'yaxis'

# %%
#Implement PART B:
test1 = df.read_csv("test1.csv")
test2 = df.read_csv("test2.csv")

# %%
#Implement PART C:

# %%
#Implement Part D:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import math
import random
import seaborn as sns

matplotlib.pyplot.scatter
df1 = pd.read_csv("train1.csv") 
df2 = pd.read_csv("train2.csv") 
df2m = pd.read_csv("train2_modified.csv") #will be used in Part D


df1_numpy = df1.values
df1_x1_numpy = df1['x1'].values
df1_x2_numpy = df1['x2'].values

df2_numpy = df2.values
df2_x1_numpy = df2['x1'].values
df2_x2_numpy = df2['x2'].values

df1_class0 = df1[df1['y']==0]
df1_class1 = df1[df1['y']==1]

df2_class0 = df2[df2['y']==0]
df2_class1 = df2[df2['y']==1]

df1_class0_x1 = df1_class0['x1'].values
df1_class0_x2 = df1_class0['x2'].values

df1_class1_x1 = df1_class1['x1'].values
df1_class1_x2 = df1_class1['x2'].values


df2_class0_x1 = df2_class0['x1'].values
df2_class0_x2 = df2_class0['x2'].values

df2_class1_x1 = df2_class1['x1'].values
df2_class1_x2 = df2_class1['x2'].values



###Calculation of Covariance Matrix

################

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg

axs[0].set(title='Dataset 1',xlabel='x1', ylabel='N')
axs[0].hist(df1_class0_x1, bins=n_bins, fc=(1, 0, 0, 0.5))
axs[0].hist(df1_class1_x1, bins=n_bins, fc=(0, 0, 1, 0.5))

axs[1].set(title='Dataset 1',xlabel='x2', ylabel='N')
axs[1].hist(df1_class0_x2, bins=n_bins, fc=(1, 0, 0, 0.5))
axs[1].hist(df1_class1_x2, bins=n_bins, fc=(0, 0, 1, 0.5))

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
axs[0].set(title='Dataset 2',xlabel='x1', ylabel='N')
axs[0].hist(df2_class0_x1, bins=n_bins, fc=(1, 0, 0, 0.5))
axs[0].hist(df2_class1_x1, bins=n_bins, fc=(0, 0, 1, 0.5))

axs[1].set(title='Dataset 2',xlabel='x2', ylabel='N')
axs[1].hist(df2_class0_x2, bins=n_bins, fc=(1, 0, 0, 0.5))
axs[1].hist(df2_class1_x2, bins=n_bins, fc=(0, 0, 1, 0.5))

plt.show()

plt.gca().set(title='Plot of Dataset 1',xlabel='x1', ylabel='x2')
plt.scatter(df1_class0_x1, df1_class0_x2, s=3, c="Blue", alpha=1)
plt.scatter(df1_class1_x1, df1_class1_x2, s=3, c="Red", alpha=1)
plt.show()

plt.gca().set(title='Plot of Dataset 2',xlabel='x1', ylabel='x2')
plt.scatter(df2_class0_x1, df2_class0_x2, s=3, c="Blue", alpha=1)
plt.scatter(df2_class1_x1, df2_class1_x2, s=3, c="Red", alpha=1)
plt.show()
